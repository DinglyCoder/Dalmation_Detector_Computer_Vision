# %%
from google.colab import drive

#Connect to google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Change directory to darknet folder
# %cd "/content/drive/My Drive/darknet-master/"
# Out:
# /content/drive/My Drive/darknet-master

# %%
# !make
# !chmod +x ./darknet
# Out:
# chmod +x *.sh

# %%
#@title
#Run the model
! ./darknet detector train data/obj.data cfg/yolo-obj.cfg yolov4.conv.137 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 762.566406, iou_loss = 0.000000, total_loss = 762.566406
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.366068), count: 22, class_loss = 464.234467, iou_loss = 0.942474, total_loss = 465.176941
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.362929), count: 30, class_loss = 152.948502, iou_loss = 0.382217, total_loss = 153.330719
#  total_bbox = 163578, rewritten_bbox = 0.110651 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.086030), count: 1, class_loss = 764.971436, iou_loss = 0.004211, total_loss = 764.975647
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.407954), count: 27, class_loss = 468.588135, iou_loss = 1.709564, total_loss = 470.297699
# ...

# %%
#Test model 
# !./darknet detector test data/obj.data cfg/yolo-obj.cfg backup/yolo-obj_last.weights
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...

# %%
#validate model
! ./darknet detector map data/obj.data cfg/yolo-obj.cfg ./backup/yolo-obj_last.weights
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...

# %%
names_list = ['dalmatians15.jpg','dalmatians20.jpg','dalmatians24.jpg','dalmatians25.jpg','dalmatians9.jpg','dalmatians_31.jpg','dalmatians_5.jpg',]
model_path = ''
image_path = 'data/obj/'
output_path = ''


def test_images_by_names_list(names_list, model_path, image_path, output_path):
  """
  Makes detection on images in selected folder.
  Saves results of detection: images and files with coordinates.
  :param names_list: list of images names
  :param model_path: path to model
  :param image_path: path to folder with images
  :param output_path: path to folder to save results
  :return:
  """
  # create output folder if not exists
  if not os.path.isdir(output_path):
    os.mkdir(output_path)

  i=1
  for image in names_list:
    print("{} / {}".format(i, len(names_list)))
    # get image name
    output_image = image.split('.')[0]
    # run and save detection
    ! ./darknet detector test data/obj.data cfg/yolo-obj.cfg {model_path} -dont_show -ext_output {image_path}/{image} > {output_path}/{output_image}.txt
    # !mv predictions.jpg {output_path}/{output_image}.jpg
    i += 1

  # get list of images names
  test_images_names = [f for f in os.listdir('data/test/') if isfile(join('data/test/', f)) and
  f.endswith('jpg')]
  # run function
  test_images_by_names_list(test_images_names, 'backup/yolo-obj_last.weights', 'data/test','data/test_results')
